# %%
import pandas as pd
import numpy as np

x = np.array(pd.read_csv("data/data.csv")).reshape(-1)


sum(np.isnan(x))/sum(~np.isnan(x))
# Out:
# 0.0

# %%
import numpy as np
import pandas as pd
data = pd.read_csv('data/NCU_8.csv').iloc[:400,0:2].values

# %%
from test.pipeline import  *
DATA = [data[:,1],data[:,0]]
inp = pipeline(DATA,111)

# %%
out = predictions(inp,3.6,5,real = None)
# Out:
# 23559-WARNING-AI_warning_3: datos a validar no encontrados

# %%
val = out['output']['validation']

# %%
float(val['maximum'])
# Out:
# 0.0

# %%
val = []


for i in range(20):
    data = D.iloc[i:400+i,0:2].values
    DATA = [data[:,1],data[:,0]]
    real = np.array(pd.Series(DATA[0][200:200+20]).fillna(0))*3.6
    REAL = [real,np.array([np.max(real)]),np.array([np.mean(real),np.std(real)])]  
    inp = pipeline(DATA,111)
    out = predictions(inp,3.6,5,real = REAL)
    val.append(float(out['output']['validation']['maximum']))

# %%
import pandas as pd
import numpy as np
from scipy.signal import savgol_filter
from pipeline import *
import matplotlib.pyplot as plt
import json
D = pd.read_csv('data/NCU_8.csv')
i = 0
    # print(out['output'])

# %%
data = D.iloc[i:400+i,0:2].values
DATA = [data[:,1],data[:,0]]
inp = pipeline(DATA,sav = 69,N = 200,n= 40)
out = predictions(inp,conv=3.6,alarm = 5, sam=15,N = 200,n= 40,ret = 1) 
# out
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# /tmp/ipykernel_158443/2777358133.py in <module>
# ----> 1 data = D.iloc[i:400+i,0:2].values
#       2 DATA = [data[:,1],data[:,0]]
#       3 inp = pipeline(DATA,sav = 69,N = 200,n= 40)
#       4 out = predictions(inp,conv=3.6,alarm = 5, sam=15,N = 200,n= 40,ret = 1)
#       5 # out
#
# AttributeError: 'numpy.ndarray' object has no attribute 'iloc'

# %%
type(inp[1]) == float
# Out:
# False

# %%
for i in range(10):
    data = D.iloc[i:400+i,0:2].values
    DATA = [data[:,1],data[:,0]]
    inp = pipeline(DATA,sav = 49,N = 200,n= 40)
    out = predictions(inp,conv=3.6,alarm = 5, sam=15,N = 200,n= 40,ret = 1)   
    json_string = json.dumps(out)
    with open('json_data'+str(i)+'.json', 'w') as outfile:
        outfile.write(json_string)

# %%
# real = savgol_filter(np.array(pd.Series(DATA[0]).fillna(0))*3.6,51,1)[-200+40:-200]
# REAL = [real[0:20],np.array([np.max(real)]),np.array([np.mean(real),np.mean(real) + np.std(real)])]

# %%
imputacion de valores asentes
data_int = pd.Series(abs(array(data[0].copy()))).interpolate(method='linear', 
                                       limit_direction ='backward', 
                                       limit = 1,inplace = False)
data_int = data_int.fillna(data_int.median(skipna = True),inplace = False)


conteo de valores incompletos


comp = len(pd.Series(data[0]).dropna())/len(pd.Series(data[0]))

# %%
d = list(D[0:100000,0])
y = list(D[0:100000,1])

# %%
import config as c
import pandas as pd
from datetime import datetime
from IPython.display import clear_output
now = datetime.now()
current_time = now.strftime("%y-%m-%d %H:%M:%S")
n = c.n
N = c.N
D = pd.read_csv("data/NCU_8.csv").values
d = list(D[0:100000,0])
y = list(D[0:100000,1])

# %%
for i in range(1000):
    print(i+1,"/1000")
    data = {
    "header":{
        "empresa":"empresa",
        "id":"asdasdasdasd",
        "planta":"1234"   
    },
    
    "update_time": str(now),
    
    "data":{
        "datetime": str(d[i:i+400]),
        "values": str(y[i:i+400])
        }
}
    with open('data/jsons/inpt_data_'+str(1000-i)+'.json', 'w') as outfile:
        json.dump(data, outfile)
    clear_output(wait=True)
# Out:
# 1000 /1000

# %%
data = {
    "header":{
        "empresa":"empresa",
        "id":"asdasdasdasd",
        "planta":"1234"   
    },
    
    "update_time": str(now),
    
    "data":{
        "datetime": str(d[0:400]),
        "values": str(y[0:400])
        }
}

# %%
# %time
from pipeline import *
inp = pipeline(data = data ,sav = 111,N = 200,n= 40)
out = predictions(inp,conv=3.6,alarm = 5, sam=15,N = 200,n= 40,ret = 1)
print(json.dumps(out,indent = 4))
# Out:
# {
#     "header": {
#         "empresa": "empresa",
#         "id": "asdasdasdasd",
#         "planta": "1234"
#     },
#     "update_time": "2022-04-04 12:14:14",
#     "inputs": {
#         "input_0": "[0.74, 0.74, 0.71, 0.76, 0.82, 0.79, 0.83, 0.81, 0.8, 0.92, 0.98, 0.92, 0.93, 0.95, 0.96, 0.89, 0.85, 0.77, 0.71, 0.82, 0.96, 1.01, 0.93, 1.06, 1.04, 1.14, 1.06, 1.22, 1.16, 1.22, 1.23, 1.3, 1.33, 1.3, 1.37, 1.46, 1.4, 1.5, 1.52, 1.49, 1.62, 1.6, 1.48, 1.36, 1.35, 1.37, 1.45, 1.31, 1.37, 1.23, 1.2, 1.12, 1.01, 0.87, 0.83, 0.83, 0.87, 0.73, 0.71, 0.83, 0.98, 1.15, 1.09, 1.26, 1.21, 1.24, 1.54, 1.65, 1.77, 1.89, 1.95, 2.2, 2.16, 2.15, 2.09, 2.02, 1.95, 1.89, 1.83, 1.84, 2.01, 2.04, 2.1, 2.03, 2.1, 2.08, 2.16, 2.09, 2.08, 2.02, 1.97, 2.02, 2.1, 2.05, 2.11, 2.08, 2.07, 2.18, 2.2, 2.08, 2.14, 2.13, 1.98, 1.93, 1.91, 1.85, 1.79, 1.81, 1.79, 1.77, 1.77, 1.82, 2.07, 1.96, 2.13, 2.07, 2.2, 2.31, 2.65, 2.6, 2.87, 2.67, 2.89, 2.92, 3.12, 3.19, 3.12, 3.08, 2.92, 3.02, 3.0, 2.89, 3.08, 2.92, 2.83, 2.92, 2.75, 2.63, 2.4, 2.36, 2.29, 2.45, 2.37, 2.06, 2.08, 2.19, 2.07, 2.21, 1.88, 1.96, 1.85, 1.6, 1.72, 1.79, 1.85, 1.74, 1.93, 1.88, 1.8, 2.12, 2.0, 1.99, 1.96, 1.94, 1.77, 1.89, 1.79, 1.77, 1.61, 1.61, 1.59, 1.74, 1.82, 1.61, 1.53, 1.4, 1.34, 1.4, 1.34, 1.46, 1.41, 1.4, 1.28, 1.1, 1.23, 1.1, 0.98, 1.09, 1.28, 1.36, 1.52, 1.57, 1.62, 1.49, 1.77, 1.85, 1.98, 2.06, 2.22, 2.16, 2.06, 2.02, 2.14, 2.47, 2.13, 2.1, 2.28, 2.34, 2.07, 1.99, 2.19, 2.31, 2.41, 1.91, 1.85, 1.61,